# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010094/Computational-Thinking-and-Program-Design/blob/main/%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 組長: 莊婷伃
#
# 組員: 林庭安 陳佳敏
#
# 期末報告題目: Dcard瘋傳！手搖杯心理測驗
#
# 百字腳本初稿: 您好，請問在生活中遇到了什麼困難嗎? 手搖杯心理測驗可以為您解惑，做您人生的燈塔！
#
# 今天在您面前有四杯飲料，一杯是奶茶，一杯是紅茶，一杯是綠茶，一杯是烏龍茶，請問您會選擇哪一杯呢？
#
# 以下四種甜度冰塊， 無糖去冰，無糖正常冰，全糖去冰，全糖正常冰，您會選擇哪一種呢？
#
# 以下四種配料，波霸，珍珠，椰果，蘆薈，您會選擇哪一種呢？

# %%
########################################################
########################################################
## 背景介紹
print("歡迎來到靈性飲料店，您在這裡調配的飲品都能夠反映您的潛意識")
print("請問在生活中遇到了什麼困難嗎?")
print("手搖杯心理測驗可以為您解惑，做您人生的燈塔！")
print(" ")
print("     載      ↖️(^ω^)↗️    請     ")
print("     入      ↖️(^ω^)↗️    稍     ")
print("     中      ↖️(^ω^)↗️    等     ")
print(" ")
## 因應政府防疫措施，請在門口做實名制登記
print("為了防堵新冠肺炎進入潘朵拉的世界，這裏要為您進行實名制登記")
name = input("請在魔法的方塊上輸入您的名字，中英文都可以唷。")
## 噴酒精
print(f"你好 {name}，下方為您噴75%乙醇及量體溫，請輸入噴")
alcohol = input("")
print("        (⊙v⊙)💦💦💦💦💦💦💦💦💦    ")
print(" ")
print("        已充分為您消毒         ")
print(" ")
## 量體溫
print("恭喜您來到成為防疫妖精的最後一步")
temperature = float(input('這裡先幫您量體溫，請輸入阿拉伯數字的體溫'))
if 0 < temperature < 35.5:print('您的體溫有點過低，該不會已經成仙???')
if 35.6 <= temperature <= 37.4:print('體溫正常，恭喜您成為防疫妖精，今天想喝點什麼呢？')
if 37.4 < temperature:print('您的體溫過高，即將驅逐出境..........(連接1922)')
else: print("您的體溫有點低，再麻煩您一旁休息喔。")
### Question 1：想喝哪種茶？
print("今天在您面前有四杯飲料")
print("一杯是小濃奶茶")
print("一杯是錫蘭紅茶")
print("一杯是茉香綠茶")
print("一杯是凍頂烏龍茶")
print("請問您會選擇哪一杯呢？")
print("奶茶、紅茶、綠茶、或烏龍茶")
tea = input("你選哪一個？: ")
if tea == "奶茶" or tea == "紅茶" or tea == "綠茶" or tea == "烏龍茶": print(f"好的收到，一杯{tea}")
else: print("抱歉我們沒有賣這款飲料，您可能要另尋店家喔。")


## 甜度冰塊 
print("請問甜度冰塊？")
print("我們有四種配好的黃金比例可以做選擇。")
print("一號無糖去冰")
print("二號無糖正常冰")
print("三號全糖去冰")
print("四號全糖正常冰")
print("請問您今天想喝幾號呢？")
sugarice = input("輸入編號的阿拉伯數字即可: ")
if sugarice == "1": print("您真有眼光！無糖去冰是最多人選擇的甜度冰塊呢！")

if sugarice == "2": print("在炎熱的夏天，當然要喝清爽的無糖正常冰啦！您真內行！")

if sugarice == "3": print("看來客人您是螞蟻人！不僅全糖，還去冰！飲料加點甜，生活才會甜！")

if sugarice == "4": print("全糖正常冰是最經典的啦！果然是我們的客人！")

## 配料選擇

print("手工波霸、現煮珍珠、新鮮椰果、清爽蘆薈")
print("配料的部分您想要哪一種呢？: ")
topping = input("請輸入想要的配料:輸入配料後兩字即可 ")

if topping == "椰果" or topping == "蘆薈" or topping == "波霸" or topping == "珍珠": print(f"好的收到，要加{topping}，我們配料的部分都是免費贈送喔！")

## 分數計算 
print("傳說自己點的飲料可以反映自己的心理狀況")
print("這邊可以幫您做測試喔")
print("剛才您所點做的選擇各代表一個編號")
print(" ")
print("奶茶，無糖去冰，波霸各代表一分")
print("紅茶，無糖正常冰，珍珠各代表二分")
print("綠茶，全糖去冰，椰果各代表三分")
print("烏龍茶，全糖正常冰，蘆薈各代表四分")
print(" ")
score = float(input('請問你所調配的飲料一共拿下幾分呢？')) 
if 10 < score <= 15:print('近期的生活雖然辛苦，但馬上就會嘗到勝利的果實')
if 5 < score <= 10:print('這陣子痛苦跟困難都是暫時的，請再撐一下，一切都會迎刃而解!')
if 0 < score <= 5:print('您希望可以過個簡單又不無趣的生活，再精進自己的同時也不要忘了休息喔><')

print("這邊幫您結帳，請問您有需要使用載具嗎？")
choice1 = input("要用載具嗎？輸入yes或no： ")
if choice1 == "no": print("好的，那這邊就幫您把發票印出來。")
if choice1 == "yes": print("好的，這邊請您出示一下條碼喔。請輸入ok，表示您已出示條碼") 
code = input("")
print("嗶嗶！掃描完畢！") 
print("這樣就可以囉！")
print("那請問要使用電子支付還是付現呢")
choice1 = input("要使用電子支付嗎？輸入yes或no")
if choice1 == "no": print("好的，要付現，請輸入付現。")
if choice1 == "yes": print("好的，這邊請您出示付款條碼喔。請輸入ok，表示您已出示條碼")
code = input("")
print("已收到您的款項，請稍等明細")
print("(經過三分鐘的漫長等待...)")
print("您的飲料好囉！")
print("謝謝惠顧，歡迎再次光臨！")

# %% [markdown]
# 歡迎來到靈性飲料店，您在這裡調配的飲品都能夠反映您的潛意識!
# 請問在生活中遇到了什麼困難嗎?手搖杯心理測驗可以為您解惑，做您人生的燈塔！
#      載      ↖️(^ω^)↗️    請
#      入      ↖️(^ω^)↗️    稍
#      中      ↖️(^ω^)↗️    等
# 為了防堵新冠肺炎進入潘朵拉的世界，這裡要為您進行實名制登記，請在魔法的方塊上輸入您的名字，中英文都可以唷。:小齊
# 你好小齊，下方為您噴75%乙醇及量體溫，請輸入噴。:噴(⊙v⊙)💦💦💦💦💦💦💦💦💦，已充分為您消毒!
# 恭喜您來到成為防疫妖精的最後一步!
# 這裡先幫您量體溫，請輸入阿拉伯數字的體溫。:36.7
# 體溫正常，恭喜您成為防疫妖精，今天想喝點什麼呢？今天在您面前有四杯飲料，一杯是小濃奶茶，一杯是錫蘭紅茶，一杯是茉香綠茶，一杯是凍頂烏龍茶，請問您會選擇哪一杯呢？奶茶、紅茶、綠茶、或烏龍茶，你選哪一個？:奶茶
# 好的收到，一杯奶茶。
# 請問甜度冰塊？我們有四種配好的黃金比例可以做選擇。一號無糖去冰，二號無糖正常冰，三號全糖去冰，四號全糖正常冰，請問您今天想喝幾號呢？輸入編號的阿拉伯數字即可。:3
# 看來客人您是螞蟻人！不僅全糖，還去冰！飲料加點甜，生活才會甜！
# 手工波霸、現煮珍珠、新鮮椰果、清爽蘆薈，配料的部分您想要哪一種呢？請輸入想要的配料，輸入配料後兩字即可。:波霸
# 好的收到，要加波霸，我們配料的部分都是免費贈送喔！
# 傳說自己點的飲料可以反映自己的心理狀況，這邊可以幫您做測試喔!剛才您所點做的選擇各代表一個編號，奶茶、無糖去冰、波霸各代表一分，紅茶、無糖正常冰、珍珠各代表二分，綠茶、全糖去冰、椰果各代表三分，烏龍茶、全糖正常冰、蘆薈各代表四分，請問你所調配的飲料一共拿下幾分呢？:5
# 您希望可以過個簡單又不無趣的生活，再精進自己的同時也不要忘了休息喔><
# 這邊幫您結帳，請問您有需要使用載具嗎？輸入yes或no：Yes
# 好的，這邊請您出示一下條碼喔。請輸入ok，表示您已出示條碼:ok
# 嗶嗶！掃描完畢！這樣就可以囉！那請問要使用電子支付還是付現呢，要使用電子支付嗎？輸入yes或no :no
# 好的，要付現，請輸入付現。:付現
# 已收到您的款項，請稍等明細!
# (經過三分鐘的漫長等待...)
# 您的飲料好囉！謝謝惠顧，歡迎再次光臨！
#
#
#
# 歡迎來到靈性飲料店，您在這裡調配的飲品都能夠反映您的潛意識!
# 請問在生活中遇到了什麼困難嗎?手搖杯心理測驗可以為您解惑，做您人生的燈塔！
#      載      ↖️(^ω^)↗️    請
#      入      ↖️(^ω^)↗️    稍
#      中      ↖️(^ω^)↗️    等
# 為了防堵新冠肺炎進入潘朵拉的世界，這裡要為您進行實名制登記，請在魔法的方塊上輸入您的名字，中英文都可以唷。:小齊
# 你好小齊，下方為您噴75%乙醇及量體溫，請輸入噴。:噴(⊙v⊙)💦💦💦💦💦💦💦💦💦，已充分為您消毒!
# 恭喜您來到成為防疫妖精的最後一步!
# ¬---Q1---
# 這裡先幫您量體溫，請輸入阿拉伯數字的體溫。
# ====A1=====
# :35.5
# 您的體溫有點過低，該不會已經成仙???
# ====A2=====
# :35.6
# 體溫正常，恭喜您成為防疫妖精，今天想喝點什麼呢？
# ====A3=====
# :37.5
# 您的體溫過高，即將驅逐出境..........(連接1922)
# ====A4=====
# :35.55
# 您的體溫有點低，再麻煩您一旁休息喔。
# #A2story#
# ---Q2---
# 今天在您面前有四杯飲料，一杯是小濃奶茶，一杯是錫蘭紅茶，一杯是茉香綠茶，一杯是凍頂烏龍茶，請問您會選擇哪一杯呢？奶茶、紅茶、綠茶、或烏龍茶，你選哪一個？
# ====B1=====
# :奶茶
# 好的收到，一杯奶茶。
# ====B2=====
# :紅茶
# 好的收到，一杯紅茶。
# ====B3=====
# :綠茶
# 好的收到，一杯綠茶。
# ====B4=====
# :烏龍茶
# 好的收到，一杯烏龍茶。
# ====B5=====
# ~ending1~
# :菊花茶
# 抱歉我們沒有賣這款飲料，您可能要另尋店家喔。
# #A2-B5story#
# ---Q3---
# 請問甜度冰塊？我們有四種配好的黃金比例可以做選擇。一號無糖去冰，二號無糖正常冰，三號全糖去冰，四號全糖正常冰，請問您今天想喝幾號呢？輸入編號的阿拉伯數字即可。
# ====C1=====
# :1
# 您真有眼光！無糖去冰是最多人選擇的甜度冰塊呢！
# ====C2=====
# :2
# 在炎熱的夏天，當然要喝清爽的無糖正常冰啦！您真內行
# ====C3=====
# :3
# 看來客人您是螞蟻人！不僅全糖，還去冰！飲料加點甜，生活才會甜！
# ====C4=====
# :4
# 全糖正常冰是最經典的啦！果然是我們的客人！
# ---Q4---
# 手工波霸、現煮珍珠、新鮮椰果、清爽蘆薈，配料的部分您想要哪一種呢？請輸入想要的配料，輸入配料後兩字即可。
# ====D1=====
# :波霸
# 好的收到，要加波霸，我們配料的部分都是免費贈送喔！
# ====D2=====
# :珍珠
# 好的收到，要加珍珠，我們配料的部分都是免費贈送喔！
# ====D3=====
# :椰果
# 好的收到，要加椰果，我們配料的部分都是免費贈送喔！
# ====D4=====
# :蘆薈
# 好的收到，要加蘆薈，我們配料的部分都是免費贈送喔！
# ---Q5---
# 傳說自己點的飲料可以反映自己的心理狀況，這邊可以幫您做測試喔!剛才您所點做的選擇各代表一個編號，奶茶、無糖去冰、波霸各代表一分，紅茶、無糖正常冰、珍珠各代表二分，綠茶、全糖去冰、椰果各代表三分，烏龍茶、全糖正常冰、蘆薈各代表四分，請問你所調配的飲料一共拿下幾分呢？
# ====E1=====
# :5
# 您希望可以過個簡單又不無趣的生活，再精進自己的同時也不要忘了休息喔><
# ====E2=====
# :10
# 這陣子痛苦跟困難都是暫時的，請再撐一下，一切都會迎刃而解!
# ====E3=====
# :15
# 近期的生活雖然辛苦，但馬上就會嘗到勝利的果實
# ---Q6---
# 這邊幫您結帳，請問您有需要使用載具嗎？輸入yes或no!
# ====F1=====
# :yes
# 好的，這邊請您出示一下條碼喔。
# ====F2=====
# :no
# 好的，那這邊就幫您把發票印出來。
# #A2-B5+F1story#
# 請輸入ok，表示您已出示條碼。
# :ok
# 嗶嗶！掃描完畢！這樣就可以囉！
# ---Q7---
# 那請問要使用電子支付還是付現呢，要使用電子支付嗎？輸入yes或no。
# ====G1=====
# :yes
# 好的，這邊請您出示付款條碼喔。
# ====G2=====
# :no
# 好的，要付現。
# #A2-B5+F1+G1story#
# ~ending2~
# 請輸入ok，表示您已出示條碼。
# :ok
# 已收到您的款項，請稍等明細!
# (經過三分鐘的漫長等待...)
# 您的飲料好囉！謝謝惠顧，歡迎再次光臨!
# #A2-B5+F1+G2story#
# ~ending3~
# 請輸入付現。
# :付現
# 已收到您的款項，請稍等明細!
# (經過三分鐘的漫長等待...)
# 您的飲料好囉！謝謝惠顧，歡迎再次光臨!
# #A2-B5+F2story#
# ---Q7---
# 那請問要使用電子支付還是付現呢，要使用電子支付嗎？輸入yes或no。
# ====G1=====
# :yes
# 好的，這邊請您出示付款條碼喔。
# ====G2=====
# :no
# 好的，要付現。
# #A2-B5+F2+G1story#
# ~ending4~
# 請輸入ok，表示您已出示條碼。
# :ok
# 已收到您的款項，請稍等明細!
# (經過三分鐘的漫長等待...)
# 您的飲料好囉！謝謝惠顧，歡迎再次光臨!
# #A2-B5+F2+G2story#
# ~ending5~
# 請輸入付現。
# :付現
# 已收到您的款項，請稍等明細!
# (經過三分鐘的漫長等待...)
# 您的飲料好囉！謝謝惠顧，歡迎再次光臨!
